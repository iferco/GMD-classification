# %% [markdown]
# ## Read full CSV

# %%
import pandas as pd
# %pip install music21
from music21 import *
#¡Atencion! Aquí tu path a una carpeta en la que este un archivo MuseScore3.exe
#yo copie el archivo MuseScore3.exe de la carpeta de instalacion a la carpeta en la que tengo el repositorio
path_to_musescore = 'C:/Users/ifc04/OneDrive/Desktop/UNIVERSIDAD/Audio and Music Processing Lab/Lab 3 - Ethnomusicology/GMD-classification/data/'
environment.set('musescoreDirectPNGPath', path_to_musescore)
# Out:
# Requirement already satisfied: music21 in c:\users\ifc04\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (8.1.0)
# Requirement already satisfied: webcolors>=1.5 in c:\users\ifc04\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from music21) (1.12)
# Requirement already satisfied: joblib in c:\users\ifc04\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from music21) (1.2.0)
# Requirement already satisfied: matplotlib in c:\users\ifc04\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from music21) (3.5.3)
# Requirement already satisfied: chardet in c:\users\ifc04\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from music21) (5.1.0)
# Requirement already satisfied: more-itertools in c:\users\ifc04\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from music21) (9.1.0)
# Requirement already satisfied: requests in c:\users\ifc04\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from music21) (2.28.1)
# Requirement already satisfied: jsonpickle in c:\users\ifc04\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from music21) (2.2.0)
# Requirement already satisfied: numpy in c:\users\ifc04\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from music21) (1.23.4)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ifc04\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->music21) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\ifc04\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->music21) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\ifc04\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->music21) (20.9)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\ifc04\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->music21) (9.3.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\ifc04\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->music21) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ifc04\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->music21) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\ifc04\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->music21) (0.11.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\ifc04\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests->music21) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ifc04\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests->music21) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ifc04\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests->music21) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\ifc04\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests->music21) (1.26.13)
# Requirement already satisfied: six>=1.5 in c:\users\ifc04\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from python-dateutil>=2.7->matplotlib->music21) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0 -> 23.0.1
# [notice] To update, run: C:\Users\ifc04\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
#Read galician_musicxml_full.csv but is in father folder
df = pd.read_csv('../galician_musicxml_full.csv',quotechar='"',skipinitialspace=True)

#df = pd.read_csv('galician_musicxml_full.csv',quotechar='"',skipinitialspace=True)

#drop first column
#name first column id
df = df.rename(columns={'Unnamed: 0': 'id'})
#In this case we dont need the first column because index of row=name of musicxml file
#have in mind that we do need it for the other csv files
df
# Out:
#       id                   name                   location
# 0      0   Muiñeira dos Fosados                    Fosados
# 1      1       Detrás das airas                      airas
# 2      2   Muiñeira de Quindous                   Quindous
# 3      3   Muiñeira de Quindous  Quindous, Cervantes, Lugo
# 4      4               Muiñeira                        NaN
# ..   ...                    ...                        ...
# 449  449    Carballesa do Incio                      Incio
# 450  450  Muiñeira de Vilarmide     Vilarmide, A Pontenova
# 451  451               Na Ruada                        NaN
# 452  452  Danza Anterga de Lugo                       Lugo
# 453  453    Carballesa do Incio                      Incio
#
# [454 rows x 3 columns]

# %% [markdown]
# ## Read file with all the locations

# %%
#Read galician_musicxml_full.csv in father folder
df_located = pd.read_csv('../galician_musicxml_located.csv',quotechar='"',skipinitialspace=True)
#df_located = pd.read_csv('galician_musicxml_located.csv',quotechar='"',skipinitialspace=True)
#Rename first column to id
df_located = df_located.rename(columns={df_located.columns[0]: "id"})
"""
Have in mind that for this case the id IS important. ID is the name of the musicxml file
"""
df_located
# Out:
#       id                     name  parroquia     concellu    province
# 0      1         Detrás das airas        NaN     As Airas     Ourense
# 1      2     Muiñeira de Quindous   Quindous    Cervantes        Lugo
# 2      3     Muiñeira de Quindous   Quindous    Cervantes        Lugo
# 3      5     Muiñeira de Monforte        NaN     Monforte        Lugo
# 4      6      Muiñeira de Ventosa        NaN      Ventosa  Pontevedra
# ..   ...                      ...        ...          ...         ...
# 255  446  Ribeirana de Pontevedra        NaN   Pontevedra  Pontevedra
# 256  449      Carballesa do Incio        NaN      O Incio        Lugo
# 257  450    Muiñeira de Vilarmide  Vilarmide  A Pontenova        Lugo
# 258  452    Danza Anterga de Lugo        NaN         Lugo        Lugo
# 259  453      Carballesa do Incio        NaN      O Incio        Lugo
#
# [260 rows x 5 columns]

# %%
#Example, let's say we want to load a Muiñeira de Quindous
#Show all the rows where the id is equal to "Muiñeira de Quindous"
df_located.loc[df_located['name'] == 'Muiñeira de Quindous']
# Out:
#    id                  name parroquia   concellu province
# 1   2  Muiñeira de Quindous  Quindous  Cervantes     Lugo
# 2   3  Muiñeira de Quindous  Quindous  Cervantes     Lugo

# %%
def load_musicxml(index):
    """
    Load a musicxml file and return a music21 stream
    """
    #Set musicxml_file as a file in path data/name and name being string of the index and .musicxml
    #musicxml_file = 'data/' + str(index) + '.musicxml'
    musicxml_file =str(index) + '.musicxml'
    #The files are in the folder data
    #Load the musicxml file
    #print(musicxml_file)
    #try:
    #    s = corpus.parse(musicxml_file)

    #except Exception as e:
        #Get exception if the file is not found
    s=converter.parse(musicxml_file)
    #    return s
    return s

#Let's continue with the example, loading hte second muiñeira that appears:
#muiñeira=load_musicxml(3)
s = load_musicxml(1)
s.analyze('key')

#For loop to 453
#Create dataframe with id, name, key
df_key=pd.DataFrame(columns=['id','name','key','time_signature'])
for i in range(453):
    #get index of df_located
    index=df.loc[i]['id']
    s = load_musicxml(index)
    if s is not None:
        scoreParts = s.parts.stream()
        s = scoreParts[0]
         
        key=s.analyze('key')
        #Get name of the song in df in this case we can use the index because the index of df is the same as the id
        name=df.loc[i]['name']
        measures0 = s.getElementsByClass(stream.Measure).stream() #numero de compases
        tS = measures0[0].getElementsByClass(meter.TimeSignature).stream()[0]

        time_signature= ''+str(tS.numerator)+'/'+str(tS.denominator)
        df_key.loc[i]=[index,name, key, time_signature]



df_key
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\ifc04\OneDrive\Desktop\UNIVERSIDAD\Audio and Music Processing Lab\Lab 3 - Ethnomusicology\GMD-classification\data\example.ipynb Cell 7 in 2
#      <a href='vscode-notebook-cell:/c%3A/Users/ifc04/OneDrive/Desktop/UNIVERSIDAD/Audio%20and%20Music%20Processing%20Lab/Lab%203%20-%20Ethnomusicology/GMD-classification/data/example.ipynb#W6sZmlsZQ%3D%3D?line=19'>20</a> #Let's continue with the example, loading hte second muiñeira that appears:
#      <a href='vscode-notebook-cell:/c%3A/Users/ifc04/OneDrive/Desktop/UNIVERSIDAD/Audio%20and%20Music%20Processing%20Lab/Lab%203%20-%20Ethnomusicology/GMD-classification/data/example.ipynb#W6sZmlsZQ%3D%3D?line=20'>21</a> #muiñeira=load_musicxml(3)
#      <a href='vscode-notebook-cell:/c%3A/Users/ifc04/OneDrive/Desktop/UNIVERSIDAD/Audio%20and%20Music%20Processing%20Lab/Lab%203%20-%20Ethnomusicology/GMD-classification/data/example.ipynb#W6sZmlsZQ%3D%3D?line=21'>22</a> s = load_musicxml(1)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/ifc04/OneDrive/Desktop/UNIVERSIDAD/Audio%20and%20Music%20Processing%20Lab/Lab%203%20-%20Ethnomusicology/GMD-classification/data/example.ipynb#W6sZmlsZQ%3D%3D?line=22'>23</a> s.analyze('key')
#      <a href='vscode-notebook-cell:/c%3A/Users/ifc04/OneDrive/Desktop/UNIVERSIDAD/Audio%20and%20Music%20Processing%20Lab/Lab%203%20-%20Ethnomusicology/GMD-classification/data/example.ipynb#W6sZmlsZQ%3D%3D?line=24'>25</a> #For loop to 453
#      <a href='vscode-notebook-cell:/c%3A/Users/ifc04/OneDrive/Desktop/UNIVERSIDAD/Audio%20and%20Music%20Processing%20Lab/Lab%203%20-%20Ethnomusicology/GMD-classification/data/example.ipynb#W6sZmlsZQ%3D%3D?line=25'>26</a> #Create dataframe with id, name, key
#      <a href='vscode-notebook-cell:/c%3A/Users/ifc04/OneDrive/Desktop/UNIVERSIDAD/Audio%20and%20Music%20Processing%20Lab/Lab%203%20-%20Ethnomusicology/GMD-classification/data/example.ipynb#W6sZmlsZQ%3D%3D?line=26'>27</a> df_key=pd.DataFrame(columns=['id','name','key','time_signature'])
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\music21\stream\base.py:3424, in Stream.analyze(self, method, **keywords)
#    3422 from music21.analysis import discrete
#    3423 # pass this stream to the analysis procedure
# -> 3424 return discrete.analyzeStream(self, method, **keywords)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\music21\analysis\discrete.py:1336, in analyzeStream(streamObj, method, **keywords)
#    1334     obj = analysisClassName()
#    1335     # environLocal.printDebug(['analysis method used:', obj])
# -> 1336     return obj.getSolution(streamObj)
#    1338 # if no match raise error
#    1339 raise DiscreteAnalysisException(f'no such analysis method: {method}')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\music21\analysis\discrete.py:703, in KeyWeightKeyAnalysis.getSolution(self, sStream)
#     684 '''
#     685 Return a music21 Key object defining the results of the analysis.
#     686 Do not call process before calling this method, as this method calls process.
#    (...)
#     700 <music21.key.Key of B- major>
#     701 '''
#     702 # always take a flat version here, otherwise likely to get nothing
# --> 703 solution, unused_color = self.process(sStream.flatten(), storeAlternatives=True)
#     704 # assign best solution
#     705 k = self._solutionToObject(solution)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\music21\analysis\discrete.py:625, in KeyWeightKeyAnalysis.process(self, sStream, storeAlternatives)
#     618 sStream = sStream.flatten().notesAndRests
#     619 # this is the sample distribution used in the paper, for some testing purposes
#     620 # pcDistribution = [7, 0, 5, 0, 7, 16, 0, 16, 0, 15, 6, 0]
#     621
#     622 # this is the distribution for the melody of "happy birthday"
#     623 # pcDistribution = [9, 0, 3, 0, 2, 5, 0, 2, 0, 2, 2, 0]
# --> 625 likelyKeysMajor, likelyKeysMinor = self._likelyKeys(sStream)
#     627 # find the largest correlation value to use to select major or minor as the resulting key
#     628 # values are the result of _getLikelyKeys
#     629 # each first index is the sorted results; there will be 12
#    (...)
#     638 # see which has a higher correlation coefficient, the first major or
#     639 # the first minor
#     640 if likelyKeysMajor is not None:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\music21\analysis\discrete.py:541, in KeyWeightKeyAnalysis._likelyKeys(self, sStream)
#     540 def _likelyKeys(self, sStream):
# --> 541     pcDistribution = self._getPitchClassDistribution(sStream)
#     542     # environLocal.printDebug(['process(); pcDistribution', pcDistribution])
#     544     keyResultsMajor = self._convoluteDistribution(pcDistribution, 'major')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\music21\analysis\discrete.py:370, in KeyWeightKeyAnalysis._getPitchClassDistribution(self, streamObj)
#     368             pcDist[m] += length
#     369     else:
# --> 370         pcDist[n.pitch.pitchClass] += length
#     371 return pcDist
#
# AttributeError: 'Unpitched' object has no attribute 'pitch'

# %%
df_key_located=pd.DataFrame(columns=['id','name','parroquia','concellu','province','key','time_signature'])
i=0
for i in range(260):
    #get index of df_located
    index=df_located.loc[i]['id']
    s = load_musicxml(index)
    if s is not None:
        scoreParts = s.parts.stream()
        s = scoreParts[0]
        key=s.analyze('key')
        #Get name of the song in df in this case we can use the index because the index of df is the same as the id
        name=df_located.loc[i]['name']
        parroquia=df_located.loc[i]['parroquia']
        concellu=df_located.loc[i]['concellu']
        province=df_located.loc[i]['province']
            
        measures0 = s.getElementsByClass(stream.Measure).stream() #numero de compases
        tS = measures0[0].getElementsByClass(meter.TimeSignature).stream()[0]
        time_signature= ''+str(tS.numerator)+'/'+str(tS.denominator)
        df_key_located.loc[i]=[index,name,parroquia,concellu,province, key,time_signature]
df_key.drop(df_key.columns[0], axis=1, inplace=True)

df_key
# Out:
# <music21.stream.Part Gaita>
# <music21.stream.Part Gaita>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Gaita>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Gaita>
# <music21.stream.Part Gaita>
# <music21.stream.Part Gaita>
# <music21.stream.Part Gaita>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Gaita>
# <music21.stream.Part Gaita>
# <music21.stream.Part Gaita>
# <music21.stream.Part Gaita>
# <music21.stream.Part Gaita>
# <music21.stream.Part Voz>
# <music21.stream.Part Gaita>
# <music21.stream.Part Gaita>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Harmonica>
# <music21.stream.Part Gaita>
# <music21.stream.Part Gaita>
# <music21.stream.Part Gaita>
# <music21.stream.Part Gaita>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Gaita>
# <music21.stream.Part Gaita>
# <music21.stream.Part Gaita>
# <music21.stream.Part Gaita>
# <music21.stream.Part Gaita>
# <music21.stream.Part Gaita>
# <music21.stream.Part Gaita>
# <music21.stream.Part Gaita>
# <music21.stream.Part Gaita>
# <music21.stream.Part Gaita>
# <music21.stream.Part Gaita>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Gaita>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Gaita>
# <music21.stream.Part Gaita>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Gaita>
# <music21.stream.Part Gaita>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Gaita>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Gaita>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Gaita>
# <music21.stream.Part Gaita>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Voz>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Gaita>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Gaita>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Gaita>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Gaita>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Gaita>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Gaita>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Gaita>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Gaita>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
# <music21.stream.Part Bagpipes>
#          key time_signature
# 0    b minor            4/4
# 1    a minor            4/4
# 2    g minor            3/4
# 3    G major            4/4
# 4    G major            4/4
# ..       ...            ...
# 448  C major            2/4
# 449  C major            2/4
# 450  C major            6/8
# 451  C major            2/4
# 452  C major            2/4
#
# [453 rows x 2 columns]

# %%
df_key_located.drop(df_key_located.columns[0], axis=1, inplace=True)

df_key_located
# Out:
#                         name  parroquia     concellu    province      key  \
# 0           Detrás das airas        NaN     As Airas     Ourense  a minor
# 1       Muiñeira de Quindous   Quindous    Cervantes        Lugo  g minor
# 2       Muiñeira de Quindous   Quindous    Cervantes        Lugo  G major
# 3       Muiñeira de Monforte        NaN     Monforte        Lugo  G major
# 4        Muiñeira de Ventosa        NaN      Ventosa  Pontevedra  F major
# ..                       ...        ...          ...         ...      ...
# 255  Ribeirana de Pontevedra        NaN   Pontevedra  Pontevedra  C major
# 256      Carballesa do Incio        NaN      O Incio        Lugo  C major
# 257    Muiñeira de Vilarmide  Vilarmide  A Pontenova        Lugo  C major
# 258    Danza Anterga de Lugo        NaN         Lugo        Lugo  C major
# 259      Carballesa do Incio        NaN      O Incio        Lugo  C major
#
#     time_signature
# 0              4/4
# 1              3/4
# 2              4/4
# 3              4/4
# 4              4/4
# ..             ...
# 255            6/8
# 256            2/4
# 257            6/8
# 258            2/4
# 259            2/4
#
# [260 rows x 6 columns]

# %%
s=load_musicxml(1)
scoreParts = s.parts.stream()
my_score = scoreParts[0]
#print all notes in the score
measure_list= my_score.getElementsByClass(stream.Measure).stream() 
count=0

#List 1: Pregunta_1
Pregunta_1 = []
#List 2: Respuesta_1
Respuesta_1 = []
#List 3: Pregunta_2
Pregunta_2 = []
#List 4: Respuesta_2
Respuesta_2 = []

duration=0
 
for i in measure_list:
    print("Measure", i)
    #Print the notes in the measure
    notes=i.flat.notes
    
    for n in notes:
        #GraceDuration unlinked type:16th quarterLength:0.0 print adorno
        if not n.duration.quarterLength==0.0:
            tuple=(n.pitch.name, n.duration.quarterLength)
            duration+=n.duration.quarterLength
            if duration <= 6:
                Pregunta_1.append(tuple)
            if duration > 6 and duration <= 12:
                Respuesta_1.append(tuple)
            if duration > 12 and duration <= 18:
                Pregunta_2.append(tuple)
            if duration > 18 and duration <= 24:
                Respuesta_2.append(tuple)
            print(tuple)
        

    count=count+1
    if count==10:
        break
 
#Pregunta
print("Pregunta_1", Pregunta_1)
print("Pregunta_2", Pregunta_2)
#Respuesta
print("Respuesta_1", Respuesta_1)
print("Respuesta_2", Respuesta_2)
#for n in my_score.flat.notes:
    #if n.isNote:
        #print(n)
    #if not n.isNote:
    #    print(n)
# Out:
# Measure <music21.stream.Measure 1 offset=0.0>
# ('G', 1.0)
# ('C', 0.5)
# Measure <music21.stream.Measure 2 offset=3.0>
# ('B', 0.5)
# ('G', 0.5)
# ('B', 0.5)
# ('A', 0.5)
# ('F', 0.5)
# ('A', 0.5)
# Measure <music21.stream.Measure 3 offset=6.0>
# ('G', 1.0)
# ('E', 0.5)
# ('C', 0.5)
# ('E', 0.5)
# ('G', 0.5)
# Measure <music21.stream.Measure 4 offset=9.0>
# ('F', 1.0)
# ('D', 0.5)
# ('B', 0.5)
# ('D', 0.5)
# ('F', 0.5)
# Measure <music21.stream.Measure 5 offset=12.0>
# ('A', 1.0)
# ('G', 0.5)
# ('G', 1.0)
# ('C', 0.5)
# Measure <music21.stream.Measure 6 offset=15.0>
# ('B', 0.5)
# ('G', 0.5)
# ('B', 0.5)
# ('A', 0.5)
# ('F', 0.5)
# ('A', 0.5)
# Measure <music21.stream.Measure 7 offset=18.0>
# ('G', 1.0)
# ('E', 0.5)
# ('C', 0.5)
# ('E', 0.5)
# ('G', 0.5)
# Measure <music21.stream.Measure 8 offset=21.0>
# ('G', 0.5)
# ('A', 0.5)
# ('G', 0.5)
# ('F', 0.5)
# ('E', 0.5)
# ('D', 0.5)
# Measure <music21.stream.Measure 9 offset=24.0>
# ('C', 1.5)
# ('G', 1.0)
# ('C', 0.5)
# Measure <music21.stream.Measure 10 offset=27.0>
# ('C', 1.5)
# ('E', 0.5)
# ('C', 0.5)
# ('E', 0.5)
# Pregunta_1 [('G', 1.0), ('C', 0.5), ('B', 0.5), ('G', 0.5), ('B', 0.5), ('A', 0.5), ('F', 0.5), ('A', 0.5), ('G', 1.0), ('E', 0.5)]
# Pregunta_2 [('G', 1.0), ('C', 0.5), ('B', 0.5), ('G', 0.5), ('B', 0.5), ('A', 0.5), ('F', 0.5), ('A', 0.5), ('G', 1.0), ('E', 0.5)]
# Respuesta_1 [('C', 0.5), ('E', 0.5), ('G', 0.5), ('F', 1.0), ('D', 0.5), ('B', 0.5), ('D', 0.5), ('F', 0.5), ('A', 1.0), ('G', 0.5)]
# Respuesta_2 [('C', 0.5), ('E', 0.5), ('G', 0.5), ('G', 0.5), ('A', 0.5), ('G', 0.5), ('F', 0.5), ('E', 0.5), ('D', 0.5), ('C', 1.5)]

# %%
#Both df to csv
#rename first index to id
df_key.to_csv('df_key_ts.csv')
df_key_located.to_csv('df_key_located_ts.csv')

# %%
#Coordenadas
# !pip install geopy
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="galician_music")
location = geolocator.geocode("Lugo, A Fonsagrada")
print(location.longitude)
print(location.latitude)
# Out:
# Requirement already satisfied: geopy in c:\users\ifc04\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (2.3.0)
# Requirement already satisfied: geographiclib<3,>=1.52 in c:\users\ifc04\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from geopy) (2.0)
# -7.0676605
# 43.1248311
# [notice] A new release of pip is available: 23.0 -> 23.0.1
# [notice] To update, run: C:\Users\ifc04\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
