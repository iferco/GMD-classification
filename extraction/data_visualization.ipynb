# %%
# !pip install folium
# !pip install geopy
# Out:
# Requirement already satisfied: folium in c:\users\ifc04\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (0.14.0)
# Requirement already satisfied: numpy in c:\users\ifc04\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from folium) (1.23.4)
# Requirement already satisfied: branca>=0.6.0 in c:\users\ifc04\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from folium) (0.6.0)
# Requirement already satisfied: requests in c:\users\ifc04\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from folium) (2.28.1)
# Requirement already satisfied: jinja2>=2.9 in c:\users\ifc04\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from folium) (3.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ifc04\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jinja2>=2.9->folium) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ifc04\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests->folium) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ifc04\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests->folium) (2022.12.7)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\ifc04\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests->folium) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\ifc04\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests->folium) (1.26.13)
# [notice] A new release of pip is available: 23.0 -> 23.0.1
# [notice] To update, run: C:\Users\ifc04\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Requirement already satisfied: geopy in c:\users\ifc04\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (2.3.0)
# Requirement already satisfied: geographiclib<3,>=1.52 in c:\users\ifc04\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from geopy) (2.0)
# [notice] A new release of pip is available: 23.0 -> 23.0.1
# [notice] To update, run: C:\Users\ifc04\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import folium
import pandas as pd
from folium.plugins import MarkerCluster
from geopy.geocoders import Nominatim
#read galician_musicxml_located.csv from paretn folder
#path='../galician_musicxml_located.csv'
path='../data/data_located.csv'
df = pd.read_csv(path,quotechar='"',skipinitialspace=True)

#df = pd.read_csv('galician_musicxml_full.csv',quotechar='"',skipinitialspace=True)

#drop first column
#name first column id
#df = df.rename(columns={'Unnamed: 0': 'id'})
#drop id
#df = df.drop(['id'], axis=1)
df
# Out:
#       id                     name  parroquia     concellu    province  \
# 0      1         Detrás das airas        NaN     As Airas     Ourense
# 1      2     Muiñeira de Quindous   Quindous    Cervantes        Lugo
# 2      3     Muiñeira de Quindous   Quindous    Cervantes        Lugo
# 3      5     Muiñeira de Monforte        NaN     Monforte        Lugo
# 4      6      Muiñeira de Ventosa        NaN      Ventosa  Pontevedra
# ..   ...                      ...        ...          ...         ...
# 253  446  Ribeirana de Pontevedra        NaN   Pontevedra  Pontevedra
# 254  449      Carballesa do Incio        NaN      O Incio        Lugo
# 255  450    Muiñeira de Vilarmide  Vilarmide  A Pontenova        Lugo
# 256  452    Danza Anterga de Lugo        NaN         Lugo        Lugo
# 257  453      Carballesa do Incio        NaN      O Incio        Lugo
#
#          key time_signature  ratio_negras_corcheas muiñeira_type
# 0    C major            6/8               0.246575            C1
# 1    C major            6/8               0.312500            C1
# 2    C major            6/8               0.307692            C1
# 3    C major            6/8               0.240000            C1
# 4    C major            6/8               0.160000            C1
# ..       ...            ...                    ...           ...
# 253  C major            6/8               0.388889            C2
# 254  C major            2/4               0.126984            C1
# 255  C major            6/8               0.092025            C2
# 256  C major            2/4               0.181818            C1
# 257  C major            2/4               0.142857            C1
#
# [258 rows x 9 columns]

# %%
#print number of rows
print('Number of rows: ',len(df))
#if province, parroquia and concellu is empty, remove row
for index, row in df.iterrows():
    if pd.isnull(row['province']) and pd.isnull(row['parroquia']) and pd.isnull(row['concellu']):
        df = df.drop(index)
print('Number of rows after removing empty values: ',len(df))
# Out:
# Number of rows:  258
# Number of rows after removing empty values:  258

# %%
#use the dataframe to count the number of all muiñeiras by province and also with key not C
df.groupby(['province','key']).count()
# get only the keys
# Out:
#                      id  name  parroquia  concellu  time_signature  \
# province    key
# A Coruña    C major  55    55         44        52              55
#             F major   2     2          1         2               2
#             G major   1     1          1         1               1
#             a minor   4     4          4         4               4
#             c minor   3     3          2         3               3
#             d minor   1     1          0         1               1
#             e minor   1     1          1         1               1
# A Coruña    C major   1     1          1         1               1
#             a minor   1     1          1         1               1
# Asturies    C major   2     2          2         2               2
#             F major   2     2          0         2               2
# Coruña      C major   1     1          0         1               1
# León        C major   2     2          0         2               2
# Lugo        C major  75    75         43        72              75
#             F major   1     1          0         1               1
#             G major   1     1          0         1               1
#             a minor   2     2          1         2               2
#             c minor   1     1          1         1               1
#             f minor   1     1          1         1               1
# Ourense     C major  19    19         11        19              19
#             F major   2     2          1         2               2
#             G major   2     2          2         2               2
#             a minor   3     3          1         3               3
#             c minor   1     1          1         1               1
# Ourense     C major   1     1          0         1               1
# Pontevedra  C major  43    43         14        36              43
#             F major   9     9          7         8               9
#             G major   1     1          0         1               1
#             a minor   2     2          1         1               2
#             c minor   2     2          1         2               2
#             d minor   1     1          1         0               1
# Pontevedra  c minor   1     1          1         1               1
# Portugal    C major   1     1          1         1               1
#
#                      ratio_negras_corcheas  muiñeira_type
# province    key
# A Coruña    C major                     55             55
#             F major                      2              2
#             G major                      1              1
#             a minor                      4              4
#             c minor                      3              3
#             d minor                      1              1
#             e minor                      1              1
# A Coruña    C major                      1              1
#             a minor                      1              1
# Asturies    C major                      2              2
#             F major                      2              2
# Coruña      C major                      1              1
# León        C major                      2              2
# Lugo        C major                     75             74
#             F major                      1              1
#             G major                      1              1
#             a minor                      2              2
#             c minor                      1              1
#             f minor                      1              1
# Ourense     C major                     19             19
#             F major                      2              2
#             G major                      2              2
#             a minor                      3              3
#             c minor                      1              1
# Ourense     C major                      1              1
# Pontevedra  C major                     43             42
#             F major                      9              9
#             G major                      1              1
#             a minor                      2              2
#             c minor                      2              2
#             d minor                      1              1
# Pontevedra  c minor                      1              0
# Portugal    C major                      1              1

# %%
import numpy as np
import matplotlib.pyplot as plt
#list of all possible keys from the df
keys = df['key'].unique()
#append province to keys as the first element
keys = np.append('province',keys)
#use this as the columns for a new dataframe
df2 = pd.DataFrame(columns=keys)
#Now we will iterate over the provinces and count the number of muiñeiras in each key
for province in df['province'].unique():
    #add this to province column
    df2 = df2.append({'province':province},ignore_index=True)
#set the province as the index
 
#Quick fix of dataframe: as seen before, there are some wrong provinces because of spaces
# and everything (the problems of manually editing csvs... But we can fix them!).
for index, row in df.iterrows():
    if row['province']==' Ourense ':
        df.loc[index,'province']='Ourense'
    if row['province']==' Ourense':
        df.loc[index,'province']='Ourense'
    if row['province']=='A Coruña ':
        df.loc[index,'province']='A Coruña'
    if row['province']==' A Coruña':
        df.loc[index,'province']='A Coruña'
    #if province == Coruña change to A Coruña
    if row['province']=='Coruña':
        df.loc[index,'province']='A Coruña'
    #if is equal to Pontevedra change to Pontevedra
    if row['province']=='Pontevedra ':
        df.loc[index,'province']='Pontevedra'



#list of provinces
provinces = df['province'].unique()

print(list)
#get me a count of all C major muiñeiras in each province using the list and the tuples
def get_counts(province):
    C_Major_count=0
    F_Major_count=0
    a_minor_count=0
    c_minor_count=0
    G_major_count=0
    d_minor_count=0
    f_minor_count=0
    e_minor_count=0
    #iterate df and print province
    for index, row in df.iterrows():
        if row['province']==province and row['key']=='C major':
            C_Major_count+=1
        if row['province'] == province and row['key']=='F major':
            F_Major_count+=1
        if row['province'] == province and row['key']=='a minor':
            a_minor_count+=1
        if row['province'] == province and row['key']=='c minor':
            c_minor_count+=1
        if row['province'] == province and row['key']=='G major':
            G_major_count+=1
        if row['province'] == province and row['key']=='d minor':
            d_minor_count+=1
        if row['province'] == province and row['key']=='f minor':   
            f_minor_count+=1
        if row['province'] == province and row['key']=='e minor':
            e_minor_count+=1
    return C_Major_count,F_Major_count,a_minor_count,c_minor_count,G_major_count,d_minor_count,f_minor_count,e_minor_count


#Print counts
l_coruña=get_counts('A Coruña')
l_lugo=get_counts('Lugo')
l_ourense=get_counts('Ourense')
l_pontevedra=get_counts('Pontevedra')
#l1 is the first element of the previous lists

#list of keys
keys = df['key'].unique()

df2['C major'][0]=l_ourense[0]
df2['F major'][0]=l_ourense[1]
df2['a minor'][0]=l_ourense[2]
df2['c minor'][0]=l_ourense[3]
df2['G major'][0]=l_ourense[4]
df2['d minor'][0]=l_ourense[5]
df2['f minor'][0]=l_ourense[6]
df2['e minor'][0]=l_ourense[7]
#Lugo
df2['C major'][1]=l_lugo[0]
df2['F major'][1]=l_lugo[1]
df2['a minor'][1]=l_lugo[2]
df2['c minor'][1]=l_lugo[3]
df2['G major'][1]=l_lugo[4]
df2['d minor'][1]=l_lugo[5]
df2['f minor'][1]=l_lugo[6]
df2['e minor'][1]=l_lugo[7]
#Pontevedra
df2['C major'][2]=l_pontevedra[0]
df2['F major'][2]=l_pontevedra[1]
df2['a minor'][2]=l_pontevedra[2]
df2['c minor'][2]=l_pontevedra[3]
df2['G major'][2]=l_pontevedra[4]
df2['d minor'][2]=l_pontevedra[5]
df2['f minor'][2]=l_pontevedra[6]
df2['e minor'][2]=l_pontevedra[7]
#A Coruña
df2['C major'][3]=l_coruña[0]
df2['F major'][3]=l_coruña[1]
df2['a minor'][3]=l_coruña[2]
df2['c minor'][3]=l_coruña[3]
df2['G major'][3]=l_coruña[4]
df2['d minor'][3]=l_coruña[5]
df2['f minor'][3]=l_coruña[6]
df2['e minor'][3]=l_coruña[7]
#set the province as the index
#Remove rows from fourth to last
df2=df2.drop(df2.index[4:])
#Now I want to use this counts as %
#First I need to get the total number of muiñeiras in each province
#I will use the same function as before but this time I will count the number of muiñeiras in each province
def get_total(province):
    total=0
    for index, row in df.iterrows():
        if row['province']==province:
            total+=1
    return total

df2
# Out:
# <class 'list'>
# C:\Users\ifc04\AppData\Local\Temp\ipykernel_19396\955756014.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'province':province},ignore_index=True)
# C:\Users\ifc04\AppData\Local\Temp\ipykernel_19396\955756014.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'province':province},ignore_index=True)
# C:\Users\ifc04\AppData\Local\Temp\ipykernel_19396\955756014.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'province':province},ignore_index=True)
# C:\Users\ifc04\AppData\Local\Temp\ipykernel_19396\955756014.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'province':province},ignore_index=True)
# C:\Users\ifc04\AppData\Local\Temp\ipykernel_19396\955756014.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'province':province},ignore_index=True)
# C:\Users\ifc04\AppData\Local\Temp\ipykernel_19396\955756014.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'province':province},ignore_index=True)
# C:\Users\ifc04\AppData\Local\Temp\ipykernel_19396\955756014.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'province':province},ignore_index=True)
# C:\Users\ifc04\AppData\Local\Temp\ipykernel_19396\955756014.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'province':province},ignore_index=True)
# C:\Users\ifc04\AppData\Local\Temp\ipykernel_19396\955756014.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'province':province},ignore_index=True)
# C:\Users\ifc04\AppData\Local\Temp\ipykernel_19396\955756014.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'province':province},ignore_index=True)
# C:\Users\ifc04\AppData\Local\Temp\ipykernel_19396\955756014.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'province':province},ignore_index=True)
# C:\Users\ifc04\AppData\Local\Temp\ipykernel_19396\955756014.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'province':province},ignore_index=True)
#      province C major F major a minor c minor G major d minor f minor e minor
# 0     Ourense      19       2       3       1       2       0       0       0
# 1        Lugo      75       1       2       1       1       0       1       0
# 2  Pontevedra      43       9       2       3       1       1       0       0
# 3    A Coruña      57       2       5       3       1       1       0       1

# %%
#Now I will get the total number of muiñeiras in each province
total_ourense=get_total('Ourense')
total_lugo=get_total('Lugo')
total_pontevedra=get_total('Pontevedra')
total_coruña=get_total('A Coruña')
#Now I will get the percentage of each key in each province
#Ourense
df2['C major'][0]=df2['C major'][0]/total_ourense
df2['F major'][0]=df2['F major'][0]/total_ourense
df2['a minor'][0]=df2['a minor'][0]/total_ourense
df2['c minor'][0]=df2['c minor'][0]/total_ourense
df2['G major'][0]=df2['G major'][0]/total_ourense
df2['d minor'][0]=df2['d minor'][0]/total_ourense
df2['f minor'][0]=df2['f minor'][0]/total_ourense
df2['e minor'][0]=df2['e minor'][0]/total_ourense
#Lugo
df2['C major'][1]=df2['C major'][1]/total_lugo
df2['F major'][1]=df2['F major'][1]/total_lugo
df2['a minor'][1]=df2['a minor'][1]/total_lugo
df2['c minor'][1]=df2['c minor'][1]/total_lugo
df2['G major'][1]=df2['G major'][1]/total_lugo
df2['d minor'][1]=df2['d minor'][1]/total_lugo
df2['f minor'][1]=df2['f minor'][1]/total_lugo
df2['e minor'][1]=df2['e minor'][1]/total_lugo
#Pontevedra
df2['C major'][2]=df2['C major'][2]/total_pontevedra
df2['F major'][2]=df2['F major'][2]/total_pontevedra
df2['a minor'][2]=df2['a minor'][2]/total_pontevedra
df2['c minor'][2]=df2['c minor'][2]/total_pontevedra
df2['G major'][2]=df2['G major'][2]/total_pontevedra
df2['d minor'][2]=df2['d minor'][2]/total_pontevedra
df2['f minor'][2]=df2['f minor'][2]/total_pontevedra
df2['e minor'][2]=df2['e minor'][2]/total_pontevedra
#A Coruña
df2['C major'][3]=df2['C major'][3]/total_coruña
df2['F major'][3]=df2['F major'][3]/total_coruña
df2['a minor'][3]=df2['a minor'][3]/total_coruña
df2['c minor'][3]=df2['c minor'][3]/total_coruña
df2['G major'][3]=df2['G major'][3]/total_coruña
df2['d minor'][3]=df2['d minor'][3]/total_coruña
df2['f minor'][3]=df2['f minor'][3]/total_coruña
df2['e minor'][3]=df2['e minor'][3]/total_coruña
#Now I will plot the data
df2.plot(kind='bar', stacked=True, figsize=(10,10))
plt.show()
#also multiply by 100 to get the percentage except for the province column
df2['C major']=df2['C major']*100
df2['F major']=df2['F major']*100
df2['a minor']=df2['a minor']*100
df2['c minor']=df2['c minor']*100
df2['G major']=df2['G major']*100
df2['d minor']=df2['d minor']*100
df2['f minor']=df2['f minor']*100
df2['e minor']=df2['e minor']*100

#ROUND ALL THE VALUES TO 2 DECIMALS



df2
df2
# Out:
#      province    C major    F major    a minor   c minor   G major   d minor  \
# 0     Ourense   70.37037   7.407407  11.111111  3.703704  7.407407       0.0
# 1        Lugo  92.592593   1.234568   2.469136  1.234568  1.234568       0.0
# 2  Pontevedra  72.881356  15.254237   3.389831  5.084746  1.694915  1.694915
# 3    A Coruña  81.428571   2.857143   7.142857  4.285714  1.428571  1.428571
#
#     f minor   e minor
# 0       0.0       0.0
# 1  1.234568       0.0
# 2       0.0       0.0
# 3       0.0  1.428571

# %%
#Coordenadas
#"Lugo, A Fonsagrada"
def get_coordinates(place):
    geolocator = Nominatim(user_agent="galician_music")
    location = geolocator.geocode(place)
    if location is None:
        return 0, 0
    return location.latitude, location.longitude

print(get_coordinates("Laxe, A Coruña"))
# Out:
# (43.2218866, -9.0059491)

# %%
#Iterate through dataframe and print concellu, provincia and parroquias
#import sleep
from time import sleep
for index, row in df.iterrows():
    concellu=row['concellu']
    parroquia=row['parroquia']
    provincia=row['province']
    #Concat strings
    place = str(parroquia) + ", " +str(concellu) + ", " + str(provincia)
    #if any value is NaN or nan strip and keep only the right part
    if pd.isnull(parroquia):
        place = str(concellu) + ", " + str(provincia)
    if pd.isnull(concellu):
        place = provincia
    #if it has nan or Null in province, keep parroquia and concellu
    if pd.isnull(provincia):
        place = str(parroquia) + ", " +str(concellu)
    #if all is nan skip
    if pd.isnull(parroquia) and pd.isnull(concellu) and pd.isnull(provincia):
        continue
    #if place contains nan add
    if not "nan" in place:
        df.loc[index,'location'] = place
    
#drop parroquia
df = df.drop(columns=['parroquia'])
#drop concellu
df = df.drop(columns=['concellu'])
#drop province
df = df.drop(columns=['province'])

    
df
#Print location
#drop nan values
df = df.dropna(subset=['location'])
#Iterate through dataframe and get coordinates
for index, row in df.iterrows():
    
    #coordinates
    lat, lon = get_coordinates(row['location'])
    if lat == 0 and lon == 0:
        print("oops nun lo encontré", row['location'])
        #try getting locatios without parroquia, split string and get middle and last part
        place = row['location'].split(", ")
        place=place[1]+", "+place[2]
        lat, lon = get_coordinates(place)
        print("trying again", lat , lon)
        
        if lat == 0 and lon == 0:
            sleep(1)
            print(place,"still not working")
            place=place.split(", ")
            place=place[1]
            lat, lon = get_coordinates(place)
            print("trying for the last time", lat , lon)
    #add coordinates to dataframe
    df.loc[index,'lat'] = lat
    df.loc[index,'lon'] = lon
# Out:
# oops nun lo encontré Montrove, Cambre, A Coruña
# trying again 43.2803751 -8.3297129
# oops nun lo encontré Sendelle, Biomorto, A Coruña
# trying again 0 0
# Biomorto, A Coruña still not working
# trying for the last time 43.3709703 -8.3959425
# oops nun lo encontré Borreiro, Abegondo, A Coruña
# trying again 43.2104427 -8.2903237
# oops nun lo encontré Borreiro, Abegondo, A Coruña
# trying again 43.2104427 -8.2903237
# oops nun lo encontré Lema, Baldaio, A Coruña
# trying again 43.1450259 -8.5763411
# oops nun lo encontré Grixalba, Sobrado dos Monxes, A Coruña
# trying again 43.0404996 -8.02238
# oops nun lo encontré Pobra de Burón, A Fonsagrada, Lugo
# trying again 43.1248311 -7.0676605
# oops nun lo encontré Pacios de Mourisco, A Fonsagrada, Lugo
# trying again 43.1248311 -7.0676605
# oops nun lo encontré Santo Estevo de Piadela, Betanzos, A Coruña
# trying again 43.2729197 -8.2218227
# oops nun lo encontré Santiso, Vila de Cruces, Pontevedra
# trying again 42.7937228 -8.1699391
# oops nun lo encontré Entreambasaugas, Guntín de Pallares, Lugo
# trying again 42.8890081 -7.69235
# oops nun lo encontré Meiraos, Folgoso do Caurel, Lugo
# trying again 0 0
# Folgoso do Caurel, Lugo still not working
# trying for the last time 43.0462247 -7.4739921
# oops nun lo encontré Lugariño de Imende, Carballo, A Coruña
# trying again 43.2134123 -8.6891286
# oops nun lo encontré San Martín de Corbelle, A Pastoriza, Lugo
# trying again 43.3000026 -7.3511022
# oops nun lo encontré San Iago de Castillón, Pantón, Lugo
# trying again 42.50859375 -7.6423645799426865
# oops nun lo encontré Santa Maria de Oleiros, Oleiros, A Coruña
# trying again 43.3330642 -8.3170764
# oops nun lo encontré Cesures, Redondela, Pontevedra
# trying again 42.284221 -8.6085992
# oops nun lo encontré Liñeiro, Muxía, A Coruña
# trying again 43.1071193 -9.2181926
# oops nun lo encontré Lobios, Muiños, Ourense
# trying again 41.9543796 -7.9847551
# oops nun lo encontré A Seara de Montes, Cartelle, Ourense
# trying again 42.2492308 -8.0688652
# oops nun lo encontré Estromil, O Saviñao, Lugo
# trying again 42.644947650000006 -7.6394859466633855
# oops nun lo encontré Ventosela do Gateiro, Ribadavia, Ourense
# trying again 42.2880044 -8.1429521

# %%
df
#save to csv
df.to_csv('data_located.csv', index=False)

# %%
# Create a map object centered on Galicia
m = folium.Map(location=[42.7, -8.5], zoom_start=8)

#Iterate through dataframe and print concellu, provincia and parroquias
for index, row in df.iterrows():
    place = row['location']
    #Get coordinates from dataframe
    lat = row['lat']
    lon = row['lon']
    #Add marker to mapm if row
    folium.Marker([lat, lon], popup=row['name']).add_to(m)
    #Add red marker


# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a0bf444c8e9aee5e6f70b7c57cd2cc93 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a0bf444c8e9aee5e6f70b7c57cd2cc93&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a0bf444c8e9aee5e6f70b7c57cd2cc93 = L.map(
#                 &quot;map_a0bf444c8e9aee5e6f70b7c57cd2cc93&quot;,
#                 {
#                     center: [42.7, -8.5],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_30bc845deaa615029c0aca9b63b03431 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a0bf444c8e9aee5e6f70b7c57cd2cc93);
#
#
#             var marker_478b4b53f04e59b630c893d1350ed2bb = L.marker(
#                 [42.3074449, -7.9018209],
#                 {}
#             ).addTo(map_a0bf444c8e9aee5e6f70b7c57cd2cc93);
#
#
#         var popup_9c2292ccab2fd326a8ab24092a926c6c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a813b936db44e3cfbf88e1c39fa5da66 = $(`&lt;div id=&quot;html_a813b936db44e3cfbf88e1c39fa5da66&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Detrás das airas&lt;/div&gt;`)[0];
#                 popup_9c2292ccab2fd326a8ab24092a926c6c.setContent(html_a813b936db44e3cfbf88e1c39fa5da66);
#
#
#
#         marker_478b4b53f04e59b630c893d1350ed2bb.bindPopup(popup_9c2292ccab2fd326a8ab24092a926c6c)
#         ;
#
#
#
#
#             var marker_b8c15909028938016ce0a5e88a9642ea = L.marker(
#                 [42.8556407, -6.9957933],
#                 {}
#             ).addTo(map_a0bf444c8e9aee5e6f70b7c57cd2cc93);
#
#
#         var popup_02527ede173518128bac903c189cfa9c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_751093c3de5cc7053c65dd14b8364f0f = $(`&lt;div id=&quot;html_751093c3de5cc7053c65dd14b8364f0f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Muiñeira de Quindous&lt;/div&gt;`)[0];
#                 popup_02527ede173518128bac903c189cfa9c.setContent(html_751093c3de5cc7053c65dd14b8364f0f);
#
#
#
#         marker_b8c15909028938016ce0a5e88a9642ea.bindPopup(popup_02527ede173518128bac903c189cfa9c)
#         ;
#
#
#
#
#             var marker_694cbc1cfdeb06ee8775bd9e704d5749 = L.marker(
#                 [42.8556407, -6.9957933],
#                 {}
#             ).addTo(map_a0bf444c8e9aee5e6f70b7c57cd2cc93);
#
#
#         var popup_7557217d56c14a721ba3341e81c53e7d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9a9ba738f9159e7fa3dcbe7d54d5d588 = $(`&lt;div id=&quot;html_9a9ba738f9159e7fa3dcbe7d54d5d588&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Muiñeira de Quindous&lt;/div&gt;`)[0];
#                 popup_7557217d56c14a721ba3341e81c53e7d.setContent(html_9a9ba738f9159e7fa3dcbe7d54d5d588);
#
#
#
#         marker_694cbc1cfdeb06ee8775bd9e704d5749.bindPopup(popup_7557217d56c14a721ba3341e81c53e7d)
#         ;
#
#
#
#
#             var marker_5bfd81e6a2d91a771707a615db9438fa = L.marker(
#                 [42.5236693, -7.5096951],
#                 {}
#             ).addTo(map_a0bf444c8e9aee5e6f70b7c57cd2cc93);
#
#
#         var popup_8b3a00546b1a9425b4fed7ef690699dc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a5b0f6f67bf5392c723fef69b6e2863b = $(`&lt;div id=&quot;html_a5b0f6f67bf5392c723fef69b6e2863b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Muiñeira de Monforte&lt;/div&gt;`)[0];
#                 popup_8b3a00546b1a9425b4fed7ef690699dc.setContent(html_a5b0f6f67bf5392c723fef69b6e2863b);
#
#
#
#         marker_5bfd81e6a2d91a771707a615db9438fa.bindPopup(popup_8b3a00546b1a9425b4fed7ef690699dc)
#         ;
#
#
#
#
#             var marker_c2c66f114e20d7b9eb70f18289422310 = L.marker(
#                 [42.7366955, -7.97617],
#                 {}
#             ).addTo(map_a0bf444c8e9aee5e6f70b7c57cd2cc93);
#
#
#         var popup_ba0c7b6445d0bdc2b4d5415146b3eb9f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_320e6199fd2ccfff1fc7530827d45975 = $(`&lt;div id=&quot;html_320e6199fd2ccfff1fc7530827d45975&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Muiñeira de Ventosa&lt;/div&gt;`)[0];
#                 popup_ba0c7b6445d0bdc2b4d5415146b3eb9f.setContent(html_320e6199fd2ccfff1fc7530827d45975);
#
#
#
#         marker_c2c66f114e20d7b9eb70f18289422310.bindPopup(popup_ba0c7b6445d0bdc2b4d5415146b3eb9f)
#         ;
#
#
#
#
#             var marker_24e008538e081b251c2a1c7fd3ae08c6 = L.marker(
#                 [42.2182924,

# %%
# MAPA CON LAS MUIÑEIRAS CON UN RITMO DIFERENTE A 6/8
m = folium.Map(location=[42.7, -8.5], zoom_start=8)

#Iterate through dataframe and print concellu, provincia and parroquias
for index, row in df.iterrows():
    place = row['location']
    #Get coordinates from dataframe
    lat = row['lat']
    lon = row['lon']
    #Add marker to mapm if row time signature is 6/8 make it red
    if not row['time_signature'] == '6/8':
        folium.Marker([lat, lon], popup=row['name'], icon=folium.Icon(color='red')).add_to(m)
    
    #Add red marker


# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d14f9800678604c1a7a83f2f487a012d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d14f9800678604c1a7a83f2f487a012d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d14f9800678604c1a7a83f2f487a012d = L.map(
#                 &quot;map_d14f9800678604c1a7a83f2f487a012d&quot;,
#                 {
#                     center: [42.7, -8.5],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_092f5729ab61167a885ada0f40818a53 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d14f9800678604c1a7a83f2f487a012d);
#
#
#             var marker_f7eb7299cd5a1fce14ca6097f51e8d80 = L.marker(
#                 [43.0074402, -8.1269242],
#                 {}
#             ).addTo(map_d14f9800678604c1a7a83f2f487a012d);
#
#
#             var icon_c8fd94868d9eb2cd3672561e5705c766 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f7eb7299cd5a1fce14ca6097f51e8d80.setIcon(icon_c8fd94868d9eb2cd3672561e5705c766);
#
#
#         var popup_b3818e5ad4e5412e4cbd5055dc81728e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_997ad8477c5e8599f1f8e61f930c2574 = $(`&lt;div id=&quot;html_997ad8477c5e8599f1f8e61f930c2574&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Carballesa&lt;/div&gt;`)[0];
#                 popup_b3818e5ad4e5412e4cbd5055dc81728e.setContent(html_997ad8477c5e8599f1f8e61f930c2574);
#
#
#
#         marker_f7eb7299cd5a1fce14ca6097f51e8d80.bindPopup(popup_b3818e5ad4e5412e4cbd5055dc81728e)
#         ;
#
#
#
#
#             var marker_69adca2bcc7d4047d6a129c31e16ccd8 = L.marker(
#                 [42.4300046, -8.0780481],
#                 {}
#             ).addTo(map_d14f9800678604c1a7a83f2f487a012d);
#
#
#             var icon_5bbab3aceae71591357277c84a8a6d89 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_69adca2bcc7d4047d6a129c31e16ccd8.setIcon(icon_5bbab3aceae71591357277c84a8a6d89);
#
#
#         var popup_4b4deea4f74da5b0a8db2ce3f6f8ed12 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f5976d0ea564d7dc50dfe60233a68057 = $(`&lt;div id=&quot;html_f5976d0ea564d7dc50dfe60233a68057&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Carballesa&lt;/div&gt;`)[0];
#                 popup_4b4deea4f74da5b0a8db2ce3f6f8ed12.setContent(html_f5976d0ea564d7dc50dfe60233a68057);
#
#
#
#         marker_69adca2bcc7d4047d6a129c31e16ccd8.bindPopup(popup_4b4deea4f74da5b0a8db2ce3f6f8ed12)
#         ;
#
#
#
#
#             var marker_4f14ae14903abfdc8eeda969a83e081b = L.marker(
#                 [43.02234945, -8.061086732766178],
#                 {}
#             ).addTo(map_d14f9800678604c1a7a83f2f487a012d);
#
#
#             var icon_b45265a3167f9daeacc85a011698f650 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_4f14ae14903abfdc8eeda969a83e081b.setIcon(icon_b45265a3167f9daeacc85a011698f650);
#
#
#         var popup_6b9f50631af93e8dab0fb02c3420eb53 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_318c7bcfbad806a90b694be0d8f52728 = $(`&lt;div id=&quot;html_318c7bcfbad806a90b694be0d8f52728&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Muiñeira de Carelle&lt;/div&gt;`)[0];
#                 popup_6b9f50631af93e8dab0fb02c3420eb53.setContent(html_318c7bcfbad806a90b694be0d8f52728);
#
#
#
#         marker_4f14ae14903abfdc8eeda969a83e081b.bindPopup(popup_6b9f50631af93e8dab0fb02c3420eb53)
#         ;
#
#
#
#
#             var marker_228ebc38f4ddc768e8976f7641f48257 = L.marker(
#                 [42.4234102, -8.7193445],
#                 {}
#             ).addTo(map_d14f9800678604c1a7a83f2f487a012d);
#
#
#             var icon_c8826881176ea8799f5c675640d3bc35 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot

# %%
# Create a map object centered on Galicia
m = folium.Map(location=[42.7, -8.5], zoom_start=8)

#Iterate through dataframe and print concellu, provincia and parroquias
for index, row in df.iterrows():
    place = row['location']
    #Get coordinates from dataframe
    lat = row['lat']
    lon = row['lon']
    #Depending on how close the ratio_corcheas_negras is between 0.005 and 0.15 make it light green
    if row['ratio_negras_corcheas'] >= 0.000 and row['ratio_negras_corcheas'] < 0.18:
        folium.Marker([lat, lon], popup=row['name'], icon=folium.Icon(color='green')).add_to(m)
    #If it is between 0.15 and 0.3 make it green
    if row['ratio_negras_corcheas'] > 0.18 and row['ratio_negras_corcheas'] < 0.25:
        folium.Marker([lat, lon], popup=row['name'], icon=folium.Icon(color='darkgreen')).add_to(m)

    if row['ratio_negras_corcheas'] >= 0.25 and row['ratio_negras_corcheas'] < 0.3:
        folium.Marker([lat, lon], popup=row['name'], icon=folium.Icon(color='purple')).add_to(m)
    if row['ratio_negras_corcheas'] >= 0.3:
        folium.Marker([lat, lon], popup=row['name'], icon=folium.Icon(color='orange')).add_to(m)
    
    
    #Add red marker


# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3ebbfd8de50c0105423acf254894a122 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3ebbfd8de50c0105423acf254894a122&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3ebbfd8de50c0105423acf254894a122 = L.map(
#                 &quot;map_3ebbfd8de50c0105423acf254894a122&quot;,
#                 {
#                     center: [42.7, -8.5],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c0386b5b19a8dc4e3197c0b4567b5f4f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3ebbfd8de50c0105423acf254894a122);
#
#
#             var marker_2b5d43db2730badaab7949b3c05952d4 = L.marker(
#                 [42.3074449, -7.9018209],
#                 {}
#             ).addTo(map_3ebbfd8de50c0105423acf254894a122);
#
#
#             var icon_5ffe55670150fede5f6f7f347c4e52a5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkgreen&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2b5d43db2730badaab7949b3c05952d4.setIcon(icon_5ffe55670150fede5f6f7f347c4e52a5);
#
#
#         var popup_1a48a77ebfc33504065385cdbcbc0f7a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_67bb7d470939990400394ccf5facbd46 = $(`&lt;div id=&quot;html_67bb7d470939990400394ccf5facbd46&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Detrás das airas&lt;/div&gt;`)[0];
#                 popup_1a48a77ebfc33504065385cdbcbc0f7a.setContent(html_67bb7d470939990400394ccf5facbd46);
#
#
#
#         marker_2b5d43db2730badaab7949b3c05952d4.bindPopup(popup_1a48a77ebfc33504065385cdbcbc0f7a)
#         ;
#
#
#
#
#             var marker_1770e1e3e6374138424549a7608a0987 = L.marker(
#                 [42.8556407, -6.9957933],
#                 {}
#             ).addTo(map_3ebbfd8de50c0105423acf254894a122);
#
#
#             var icon_920be53f1f867a6f4893d3d89e7d8395 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;purple&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_1770e1e3e6374138424549a7608a0987.setIcon(icon_920be53f1f867a6f4893d3d89e7d8395);
#
#
#         var popup_9bf723d827213f4476ded3e9a4b50139 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cfbf9d63e0039e0b9682a39ae7c49b87 = $(`&lt;div id=&quot;html_cfbf9d63e0039e0b9682a39ae7c49b87&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Muiñeira de Quindous&lt;/div&gt;`)[0];
#                 popup_9bf723d827213f4476ded3e9a4b50139.setContent(html_cfbf9d63e0039e0b9682a39ae7c49b87);
#
#
#
#         marker_1770e1e3e6374138424549a7608a0987.bindPopup(popup_9bf723d827213f4476ded3e9a4b50139)
#         ;
#
#
#
#
#             var marker_55785cead5bce9fda2709434ed4f5d46 = L.marker(
#                 [42.8556407, -6.9957933],
#                 {}
#             ).addTo(map_3ebbfd8de50c0105423acf254894a122);
#
#
#             var icon_683c1ea6c4df0b951b8597b08aea084a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;purple&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_55785cead5bce9fda2709434ed4f5d46.setIcon(icon_683c1ea6c4df0b951b8597b08aea084a);
#
#
#         var popup_e5c4af7928eec885445649a78fce073f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5ee240f1fcd9de3f590ad129359e256c = $(`&lt;div id=&quot;html_5ee240f1fcd9de3f590ad129359e256c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Muiñeira de Quindous&lt;/div&gt;`)[0];
#                 popup_e5c4af7928eec885445649a78fce073f.setContent(html_5ee240f1fcd9de3f590ad129359e256c);
#
#
#
#         marker_55785cead5bce9fda2709434ed4f5d46.bindPopup(popup_e5c4af7928eec885445649a78fce073f)
#         ;
#
#
#
#
#             var marker_d4de8cfe130744397afb38f9eddba142 = L.marker(
#                 [42.5236693, -7.5096951],
#                 {}
#             ).addTo(map_3ebbfd8de50c0105423acf254894a122);
#
#
#             var icon_b897f9e6be8994bcf42872f752769f5d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &qu

# %%
#tabla
# columnas provincia y range 1 2 3 4
#iterar dataframe y si provincia es igual a la provincia de la columna sumar 1 al valor de la columna

# %%
#Iterate through dataframe and print all the ratio_negras_corcheas
#import plot thingy
import matplotlib.pyplot as plt 
list=[]
for index, row in df.iterrows():
    #print(row['ratio_negras_corcheas'])
    list.append(row['ratio_negras_corcheas'])

    #make me a histogram of the ratio_negras_corcheas
plt.hist(list, bins=10)
#show all values between 0 and 0.5 more detailed
# Out:
# (array([167.,  68.,  11.,   4.,   1.,   1.,   1.,   1.,   1.,   1.]),
#  array([0.        , 0.21363636, 0.42727273, 0.64090909, 0.85454545,
#         1.06818182, 1.28181818, 1.49545455, 1.70909091, 1.92272727,
#         2.13636364]),
#  <BarContainer object of 10 artists>)

# %%
import numpy as np
h=plt.hist(list, bins=100, range=(0, 0.55))
#get x from histogram
x=h[1]
#get index where y is maximum
index = np.argmax(h[0])
#get x in that index
print(x[index])
# add axis names tho
plt.xlabel('Ratio quarter to eighth notes')
#add title
plt.title('Ratio quarter to eighth in Galician muiñeiras')
plt.show()
# Out:
# 0.1265

# %%
#get row where ratio_negras_corcheas is more than 0.12 and less than 0.13, also get the second one that
#it founds

df[(df['ratio_negras_corcheas'] > 0.12) & (df['ratio_negras_corcheas'] < 0.13)]
#print name
print(df.loc[0,'name'])

#and now one that has more than 0.15 and less than 0.20
df[(df['ratio_negras_corcheas'] > 0.15) & (df['ratio_negras_corcheas'] < 0.20)]
#print name
print(df.loc[1,'name'])
# Out:
# Detrás das airas
# Muiñeira de Quindous

# %%
# Create a map object centered on Galicia
m = folium.Map(location=[42.7, -8.5], zoom_start=8)

#Iterate through dataframe and print concellu, provincia and parroquias
for index, row in df.iterrows():
    place = row['location']
    #Get coordinates from dataframe
    lat = row['lat']
    lon = row['lon']
    #If muiñeira type is 'C1' make it green
    if row['muiñeira_type'] == 'C1':
        folium.Marker([lat, lon], popup=row['name'], icon=folium.Icon(color='green')).add_to(m)
    #If it is 'C2' make it red
    if row['muiñeira_type'] == 'C2':
        folium.Marker([lat, lon], popup=row['name'], icon=folium.Icon(color='red')).add_to(m)
     #C1 ==========> P1==P2; R1!=R2
     #C2 ==========> P1!=P2; R1!=R2
    
    #Add red marker


# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_719b83c290319e7583c08bd843c0e6bf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_719b83c290319e7583c08bd843c0e6bf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_719b83c290319e7583c08bd843c0e6bf = L.map(
#                 &quot;map_719b83c290319e7583c08bd843c0e6bf&quot;,
#                 {
#                     center: [42.7, -8.5],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9a95c29176a9ca21cc1d1067a89b263e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_719b83c290319e7583c08bd843c0e6bf);
#
#
#             var marker_116d66a652afc2e4db8152e08dd922ab = L.marker(
#                 [42.3074449, -7.9018209],
#                 {}
#             ).addTo(map_719b83c290319e7583c08bd843c0e6bf);
#
#
#             var icon_1752f08d1a2cbebe9468114243b69305 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_116d66a652afc2e4db8152e08dd922ab.setIcon(icon_1752f08d1a2cbebe9468114243b69305);
#
#
#         var popup_203f28dd1b893f37baf2c8a9676b3181 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_10cbf771d32dfa81d9760df36308a976 = $(`&lt;div id=&quot;html_10cbf771d32dfa81d9760df36308a976&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Detrás das airas&lt;/div&gt;`)[0];
#                 popup_203f28dd1b893f37baf2c8a9676b3181.setContent(html_10cbf771d32dfa81d9760df36308a976);
#
#
#
#         marker_116d66a652afc2e4db8152e08dd922ab.bindPopup(popup_203f28dd1b893f37baf2c8a9676b3181)
#         ;
#
#
#
#
#             var marker_7fe5bb79e11ae4824c5a9eaf7f164f44 = L.marker(
#                 [42.8556407, -6.9957933],
#                 {}
#             ).addTo(map_719b83c290319e7583c08bd843c0e6bf);
#
#
#             var icon_149ac0f728abf0eb6a58b6567398cea2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7fe5bb79e11ae4824c5a9eaf7f164f44.setIcon(icon_149ac0f728abf0eb6a58b6567398cea2);
#
#
#         var popup_45cb7bc158cdc0f3868642df62b2bf5a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ac7072cbec76bff7f267f5afb70d1a52 = $(`&lt;div id=&quot;html_ac7072cbec76bff7f267f5afb70d1a52&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Muiñeira de Quindous&lt;/div&gt;`)[0];
#                 popup_45cb7bc158cdc0f3868642df62b2bf5a.setContent(html_ac7072cbec76bff7f267f5afb70d1a52);
#
#
#
#         marker_7fe5bb79e11ae4824c5a9eaf7f164f44.bindPopup(popup_45cb7bc158cdc0f3868642df62b2bf5a)
#         ;
#
#
#
#
#             var marker_3547b44055d45f75e4a74a4b7ea6175d = L.marker(
#                 [42.8556407, -6.9957933],
#                 {}
#             ).addTo(map_719b83c290319e7583c08bd843c0e6bf);
#
#
#             var icon_75fd2b9f1cec5d81846e76c2643b8836 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_3547b44055d45f75e4a74a4b7ea6175d.setIcon(icon_75fd2b9f1cec5d81846e76c2643b8836);
#
#
#         var popup_79cc183f188914b3f1dac0fdf82f070d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d3cdfe43a452e2e6e385de3ad43f1a62 = $(`&lt;div id=&quot;html_d3cdfe43a452e2e6e385de3ad43f1a62&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Muiñeira de Quindous&lt;/div&gt;`)[0];
#                 popup_79cc183f188914b3f1dac0fdf82f070d.setContent(html_d3cdfe43a452e2e6e385de3ad43f1a62);
#
#
#
#         marker_3547b44055d45f75e4a74a4b7ea6175d.bindPopup(popup_79cc183f188914b3f1dac0fdf82f070d)
#         ;
#
#
#
#
#             var marker_6861e933888e25c6ee95ce99da3eeb72 = L.marker(
#                 [42.5236693, -7.5096951],
#                 {}
#             ).addTo(map_719b83c290319e7583c08bd843c0e6bf);
#
#
#             var icon_2140d7fd05ee1ccd282764413baba1ae = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;ico

# %% [markdown]
# Mapa con marcadores segun la key de la muiñeira

# %%
#print the different types of keys in the dataframe
df['key'].unique()
# Out:
# array(['C major', 'F major', 'a minor', 'c minor', 'G major', 'd minor',
#        'f minor', 'e minor'], dtype=object)

# %%
# Create a map object centered on Galicia
m = folium.Map(location=[42.7, -8.5], zoom_start=8)

#Iterate through dataframe and print concellu, provincia and parroquias
for index, row in df.iterrows():
    place = row['location']
    #Get coordinates from dataframe
    lat = row['lat']
    lon = row['lon']
    #If it is 'C minor' make it light green
    if row['key'] == 'c minor':
        folium.Marker([lat, lon], popup=row['name'], icon=folium.Icon(color='lightgreen')).add_to(m)
    #If it is 'G major' make it red
    if row['key'] == 'G major':
        folium.Marker([lat, lon], popup=row['name'], icon=folium.Icon(color='red')).add_to(m)
    # if it is F major make it orange
    if row['key'] == 'F major':
        folium.Marker([lat, lon], popup=row['name'], icon=folium.Icon(color='darkpurple')).add_to(m)
    #if it is a minor
    if row['key'] == 'a minor':
        folium.Marker([lat, lon], popup=row['name'], icon=folium.Icon(color='orange')).add_to(m)
    #if it is d minor
    if row['key'] == 'd minor':
        folium.Marker([lat, lon], popup=row['name'], icon=folium.Icon(color='blue')).add_to(m)
    #if it is e minor
    if row['key'] == 'e minor':
        folium.Marker([lat, lon], popup=row['name'], icon=folium.Icon(color='gray')).add_to(m)
    #if it is f minor
    if row['key'] == 'f minor':
        folium.Marker([lat, lon], popup=row['name'], icon=folium.Icon(color='purple')).add_to(m)
    #plot c major
    #if row['key'] == 'C major':
    #    folium.Marker([lat, lon], popup=row['name'], icon=folium.Icon(color='green')).add_to(m)



# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_15a9700ae26ed69f0494d7a98ecc063f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_15a9700ae26ed69f0494d7a98ecc063f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_15a9700ae26ed69f0494d7a98ecc063f = L.map(
#                 &quot;map_15a9700ae26ed69f0494d7a98ecc063f&quot;,
#                 {
#                     center: [42.7, -8.5],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cac602b09062db4cfa823566632ed711 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_15a9700ae26ed69f0494d7a98ecc063f);
#
#
#             var marker_9576c1568d6b5848ccc0c7dc9b9f3925 = L.marker(
#                 [42.2182924, -8.7441073],
#                 {}
#             ).addTo(map_15a9700ae26ed69f0494d7a98ecc063f);
#
#
#             var icon_a8906c1617a7bd9dc180f44e580ab274 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkpurple&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9576c1568d6b5848ccc0c7dc9b9f3925.setIcon(icon_a8906c1617a7bd9dc180f44e580ab274);
#
#
#         var popup_51a8fb5db06cbdd6217f7a15039976d7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6e415c36b6a936ba03b3fd02821673ad = $(`&lt;div id=&quot;html_6e415c36b6a936ba03b3fd02821673ad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Muiñeira de Coia&lt;/div&gt;`)[0];
#                 popup_51a8fb5db06cbdd6217f7a15039976d7.setContent(html_6e415c36b6a936ba03b3fd02821673ad);
#
#
#
#         marker_9576c1568d6b5848ccc0c7dc9b9f3925.bindPopup(popup_51a8fb5db06cbdd6217f7a15039976d7)
#         ;
#
#
#
#
#             var marker_7a32c5d40eb4be7d069235cb7f815373 = L.marker(
#                 [42.0559598, -7.0906188],
#                 {}
#             ).addTo(map_15a9700ae26ed69f0494d7a98ecc063f);
#
#
#             var icon_e69daccb4ddba05574180386ec8d2298 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkpurple&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7a32c5d40eb4be7d069235cb7f815373.setIcon(icon_e69daccb4ddba05574180386ec8d2298);
#
#
#         var popup_4a69a140890a9625ef103c05404ce646 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9f787fa482cd1f9f390eabb6575947ad = $(`&lt;div id=&quot;html_9f787fa482cd1f9f390eabb6575947ad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Muiñeira do Canizo&lt;/div&gt;`)[0];
#                 popup_4a69a140890a9625ef103c05404ce646.setContent(html_9f787fa482cd1f9f390eabb6575947ad);
#
#
#
#         marker_7a32c5d40eb4be7d069235cb7f815373.bindPopup(popup_4a69a140890a9625ef103c05404ce646)
#         ;
#
#
#
#
#             var marker_1ebe1f17f5ae29ab78395abec8e56879 = L.marker(
#                 [42.9421319, -8.6453943],
#                 {}
#             ).addTo(map_15a9700ae26ed69f0494d7a98ecc063f);
#
#
#             var icon_fdbcd43237b1f11ae84645f1803b2594 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_1ebe1f17f5ae29ab78395abec8e56879.setIcon(icon_fdbcd43237b1f11ae84645f1803b2594);
#
#
#         var popup_76240763ab3c183acf3ca107fca3fb38 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5ee91c8fb0adff65331d13c2da19e70c = $(`&lt;div id=&quot;html_5ee91c8fb0adff65331d13c2da19e70c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Muiñeira de Vilaverde&lt;/div&gt;`)[0];
#                 popup_76240763ab3c183acf3ca107fca3fb38.setContent(html_5ee91c8fb0adff65331d13c2da19e70c);
#
#
#
#         marker_1ebe1f17f5ae29ab78395abec8e56879.bindPopup(popup_76240763ab3c183acf3ca107fca3fb38)
#         ;
#
#
#
#
#             var marker_aac7e04ad809d51024ce83104001344e = L.marker(
#                 [43.1516767, -8.4209222],
#                 {}
#             ).addTo(map_15a9700ae26ed69f0494d7a98ecc063f);
#
#
#             var icon_2983b7e244eabfd109f25429b63a76d4 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,

# %%
#Create class with 4 attributes, each being a tuple of latitud and longitud

coords_costa_do_morte = [
          (43.39308269143007, -9.223499498685172), 
          (43.360171263809086, -8.5935855182987), 
          (42.86272813565901, -9.38640250697399), 
          (42.894795889942, -8.547131493070601)]

coords_ancares=[
    (43.06407216991051, -7.092856719562394),
     (43.07413178098013, -6.757231712353866),
     (42.757458089540265, -7.0953597063921094),
     (42.76718609943188, -6.624539255634804)
    ]
#Courel
coords_courel=[(42.71951, -7.44513),
               (42.72724460623574, -7.023259180935899),
               (42.557159555967715, -7.391774452535561),
               (42.547941967948894, -6.969997993932699)]
               
coords_rias_baixas=[ (42.69545153782999, -9.292285368168033),
                     (42.72954631613006, -8.246817230803828),
                     (42.10248299050927, -9.060460994692036),
                      (42.18532463565332, -8.273831925246816)]

coords_a_coruña=[ (43.35034089098012, -8.565027814971595),
                  (43.71779626005273, -8.279005195808992),
                (42.88823362123043, -8.543741804075603),
                (43.1511776834362, -7.682947971160533)]

coords_fonsagrada=[ (43.42993662834845, -7.3660542568582414),
                   (43.41784560319976, -7.0310208938036665),
                   (43.03043404771632, -7.326580468861661),
                   (43.12524065161665, -7.042971216922973)]
coord_portuguese_frontier=[
    (42.22070958376089, -8.025179611018967),
    (42.20004517491106, -6.758502443951432),
    (41.766091103883234, -8.154927341800297),
    (41.80156126173536, -6.774624856958316)
]

# %%
# add new column to dataframe
df['classification'] = "Not classified"

#Now function that receives coords and itereates through the dataframe, adding a new classification 
#column
def get_muiñeiras_in_area(coords,type):
    
    #add new column to dataframe
    for index, row in df.iterrows():
        #Get coordinates from dataframe
        lat = row['lat']
        lon = row['lon']
        #Check if coordinates are inside the area
        if coords[0][0] > lat > coords[2][0] and coords[0][1] < lon < coords[1][1]:
            #If they are, append the row to the new dataframe
            df.loc[index,'classification'] = type

            

get_muiñeiras_in_area(coords_costa_do_morte, "Costa do Morte")
get_muiñeiras_in_area(coords_ancares, "Ancares")
get_muiñeiras_in_area(coords_courel, "Courel")
get_muiñeiras_in_area(coords_rias_baixas, "Rias Baixas")
get_muiñeiras_in_area(coords_a_coruña, "A Coruña")
get_muiñeiras_in_area(coords_fonsagrada, "A Fonsagrada-Asturias")
get_muiñeiras_in_area(coord_portuguese_frontier, "Portuguese Border")

# %%
df
# Out:
#       id                     name      key time_signature  \
# 0      1         Detrás das airas  C major            6/8
# 1      2     Muiñeira de Quindous  C major            6/8
# 2      3     Muiñeira de Quindous  C major            6/8
# 3      5     Muiñeira de Monforte  C major            6/8
# 4      6      Muiñeira de Ventosa  C major            6/8
# ..   ...                      ...      ...            ...
# 253  446  Ribeirana de Pontevedra  C major            6/8
# 254  449      Carballesa do Incio  C major            2/4
# 255  450    Muiñeira de Vilarmide  C major            6/8
# 256  452    Danza Anterga de Lugo  C major            2/4
# 257  453      Carballesa do Incio  C major            2/4
#
#      ratio_negras_corcheas muiñeira_type                      location  \
# 0                 0.246575            C1             As Airas, Ourense
# 1                 0.312500            C1     Quindous, Cervantes, Lugo
# 2                 0.307692            C1     Quindous, Cervantes, Lugo
# 3                 0.240000            C1                Monforte, Lugo
# 4                 0.160000            C1           Ventosa, Pontevedra
# ..                     ...           ...                           ...
# 253               0.388889            C2        Pontevedra, Pontevedra
# 254               0.126984            C1                 O Incio, Lugo
# 255               0.092025            C2  Vilarmide, A Pontenova, Lugo
# 256               0.181818            C1                    Lugo, Lugo
# 257               0.142857            C1                 O Incio, Lugo
#
#            lat       lon         classification
# 0    42.307445 -7.901821         Not classified
# 1    42.855641 -6.995793                Ancares
# 2    42.855641 -6.995793                Ancares
# 3    42.523669 -7.509695         Not classified
# 4    42.736696 -7.976170         Not classified
# ..         ...       ...                    ...
# 253  42.431888 -8.643159            Rias Baixas
# 254  42.666400 -7.363224                 Courel
# 255  43.278925 -7.191350  A Fonsagrada-Asturias
# 256  43.011844 -7.556575         Not classified
# 257  42.666400 -7.363224                 Courel
#
# [256 rows x 10 columns]

# %%
# Create a map object centered on Galicia
m = folium.Map(location=[42.7, -8.5], zoom_start=8)

#Iterate through dataframe and print concellu, provincia and parroquias
for index, row in df.iterrows():
    place = row['location']
    #Get coordinates from dataframe
    lat = row['lat']
    lon = row['lon']
    #If muiñeira classification is Ancares make it light green
    if row['classification'] == 'Ancares':
        folium.Marker([lat, lon], popup=row['name'], icon=folium.Icon(color='lightgreen')).add_to(m)
    #If muiñeira classification is Costa do Morte make it red
    if row['classification'] == 'Costa do Morte':
        folium.Marker([lat, lon], popup=row['name'], icon=folium.Icon(color='red')).add_to(m)
    #If muiñeira classification is Courel make it purple
    if row['classification'] == 'Courel':
        folium.Marker([lat, lon], popup=row['name'], icon=folium.Icon(color='purple')).add_to(m)
    #If muiñeira classification is Rias Baixas make it blue
    if row['classification'] == 'Rias Baixas':
        folium.Marker([lat, lon], popup=row['name'], icon=folium.Icon(color='blue')).add_to(m)
    #If muiñeira classification is A Coruña make it orange
    if row['classification'] == 'A Coruña':
        folium.Marker([lat, lon], popup=row['name'], icon=folium.Icon(color='orange')).add_to(m)
    #If muiñeira classification is A Fonsagrada make it cyan
    if row['classification'] == 'A Fonsagrada-Asturias':
        folium.Marker([lat, lon], popup=row['name'], icon=folium.Icon(color='black')).add_to(m)
    #If muiñeira classification is Portuguese Frontier make it grey
    if row['classification'] == 'Portuguese Border':
        folium.Marker([lat, lon], popup=row['name'], icon=folium.Icon(color='darkgreen')).add_to(m)
    
    #Add red marker


# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f4bc7ef721bccad6477c3a68dfdaa858 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f4bc7ef721bccad6477c3a68dfdaa858&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f4bc7ef721bccad6477c3a68dfdaa858 = L.map(
#                 &quot;map_f4bc7ef721bccad6477c3a68dfdaa858&quot;,
#                 {
#                     center: [42.7, -8.5],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_928585082159112a96561a38782d49ee = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f4bc7ef721bccad6477c3a68dfdaa858);
#
#
#             var marker_5a8f10ec6f0414e7f6a2e383fd139b9a = L.marker(
#                 [42.8556407, -6.9957933],
#                 {}
#             ).addTo(map_f4bc7ef721bccad6477c3a68dfdaa858);
#
#
#             var icon_830fbed4683923e89dea02cf093ac877 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgreen&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5a8f10ec6f0414e7f6a2e383fd139b9a.setIcon(icon_830fbed4683923e89dea02cf093ac877);
#
#
#         var popup_2a3468ddc84e6a02dac5e7eb44628201 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8e0c3443ea80479a5bd1e0818791f041 = $(`&lt;div id=&quot;html_8e0c3443ea80479a5bd1e0818791f041&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Muiñeira de Quindous&lt;/div&gt;`)[0];
#                 popup_2a3468ddc84e6a02dac5e7eb44628201.setContent(html_8e0c3443ea80479a5bd1e0818791f041);
#
#
#
#         marker_5a8f10ec6f0414e7f6a2e383fd139b9a.bindPopup(popup_2a3468ddc84e6a02dac5e7eb44628201)
#         ;
#
#
#
#
#             var marker_c2e171d415d8765af26155edba8a8ff5 = L.marker(
#                 [42.8556407, -6.9957933],
#                 {}
#             ).addTo(map_f4bc7ef721bccad6477c3a68dfdaa858);
#
#
#             var icon_b74c53c588afe5136824cfee59c71fd7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgreen&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c2e171d415d8765af26155edba8a8ff5.setIcon(icon_b74c53c588afe5136824cfee59c71fd7);
#
#
#         var popup_2be6b42b8e59d27cc7ac9f1a06918821 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9071391012783dcf86f36691d565f525 = $(`&lt;div id=&quot;html_9071391012783dcf86f36691d565f525&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Muiñeira de Quindous&lt;/div&gt;`)[0];
#                 popup_2be6b42b8e59d27cc7ac9f1a06918821.setContent(html_9071391012783dcf86f36691d565f525);
#
#
#
#         marker_c2e171d415d8765af26155edba8a8ff5.bindPopup(popup_2be6b42b8e59d27cc7ac9f1a06918821)
#         ;
#
#
#
#
#             var marker_5c92a968c9fb33f5cbae9e1ccad0c0b9 = L.marker(
#                 [42.2182924, -8.7441073],
#                 {}
#             ).addTo(map_f4bc7ef721bccad6477c3a68dfdaa858);
#
#
#             var icon_01da698e3f0a7cb3b567c94e0df75948 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5c92a968c9fb33f5cbae9e1ccad0c0b9.setIcon(icon_01da698e3f0a7cb3b567c94e0df75948);
#
#
#         var popup_5cc9a5ca727487f48b82c33f352f7f75 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b96249b0b21b6b836fc795018ec98b63 = $(`&lt;div id=&quot;html_b96249b0b21b6b836fc795018ec98b63&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Muiñeira de Coia&lt;/div&gt;`)[0];
#                 popup_5cc9a5ca727487f48b82c33f352f7f75.setContent(html_b96249b0b21b6b836fc795018ec98b63);
#
#
#
#         marker_5c92a968c9fb33f5cbae9e1ccad0c0b9.bindPopup(popup_5cc9a5ca727487f48b82c33f352f7f75)
#         ;
#
#
#
#
#             var marker_bc998dada72c2bdd2803b594ec209a0b = L.marker(
#                 [43.3000026, -7.3511022],
#                 {}
#             ).addTo(map_f4bc7ef721bccad6477c3a68dfdaa858);
#
#
#             var icon_5aff153440f56decee569b393be9f44a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,

# %%
#Our final csv with classification column:
df.to_csv('data_located.csv', index=False)
