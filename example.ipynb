# %% [markdown]
# # Example of use of the dataset
# Just to make it easier for future research, we will show a small example of the use of the dataset.
# We will get every muiñeira in C minor key!

# %%
#needed imports 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from  music21 import *

# %%
#We can load both the submodules and the main dataset
path='./features/' #where your data and data_located are
df = pd.read_csv(path+'data.csv')
df_located = pd.read_csv(path+'data_located.csv')

# %%
df
# Out:
#       id                   name      key time_signature  \
# 0      0   Muiñeira dos Fosados  C major            6/8
# 1      1       Detrás das airas  C major            6/8
# 2      2   Muiñeira de Quindous  C major            6/8
# 3      3   Muiñeira de Quindous  C major            6/8
# 4      4               Muiñeira  C major            6/8
# ..   ...                    ...      ...            ...
# 448  448             Carballesa  C major            2/4
# 449  449    Carballesa do Incio  C major            2/4
# 450  450  Muiñeira de Vilarmide  C major            6/8
# 451  451               Na Ruada  C major            2/4
# 452  452  Danza Anterga de Lugo  C major            2/4
#
#      ratio_corcheas_negras muiñeira_type
# 0                 0.096154            C2
# 1                 0.246575            C1
# 2                 0.312500            C1
# 3                 0.307692            C1
# 4                 0.180000            C1
# ...

# %%
df_located
# Out:
#       id                     name  parroquia     concellu    province  \
# 0      1         Detrás das airas        NaN     As Airas     Ourense
# 1      2     Muiñeira de Quindous   Quindous    Cervantes        Lugo
# 2      3     Muiñeira de Quindous   Quindous    Cervantes        Lugo
# 3      5     Muiñeira de Monforte        NaN     Monforte        Lugo
# 4      6      Muiñeira de Ventosa        NaN      Ventosa  Pontevedra
# ..   ...                      ...        ...          ...         ...
# 253  446  Ribeirana de Pontevedra        NaN   Pontevedra  Pontevedra
# 254  449      Carballesa do Incio        NaN      O Incio        Lugo
# 255  450    Muiñeira de Vilarmide  Vilarmide  A Pontenova        Lugo
# 256  452    Danza Anterga de Lugo        NaN         Lugo        Lugo
# 257  453      Carballesa do Incio        NaN      O Incio        Lugo
#
#          key time_signature  ratio_negras_corcheas muiñeira_type
# ...

# %%
#Get all muiñeiras with C minor key
print("For the main dataset we have:")
subset=df[df['key']=='c minor']
print(len(subset), "muiñeiras with C minor key")
print()
print("For the located dataset we have:")
subset_located=df_located[df_located['key']=='c minor']
print(len(subset_located), "muiñeiras with C minor key")
# Out:
# For the main dataset we have:
# 13 muiñeiras with C minor key
#
# For the located dataset we have:
# 8 muiñeiras with C minor key
